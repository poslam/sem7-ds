# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# K-means++ работает так:
#
# - Первый центр выбирается случайно
# - Каждый следующий центр выбирается с вероятностью, пропорциональной квадрату расстояния до ближайшего существующего центра
# - Это помогает избежать плохой инициализации и ускоряет сходимость

# %% [raw]
# def predict(self, X):
#         X = np.asarray(X, dtype=float)
#         labels, _ = self._assign_labels(X, self.cluster_centers_)
#         return labels
#
#     def fit_predict(self, X):
#         self.fit(X)
#         return self.labels_
#
#     def transform(self, X):
#         X = np.asarray(X, dtype=float)
#         return self._distance_sq(X, self.cluster_centers_)
#
#     def score(self, X):
#         X = np.asarray(X, dtype=float)
#         _, dist_sq = self._assign_labels(X, self.cluster_centers_)
#         return -dist_sq.sum()
